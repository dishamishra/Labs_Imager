# %% [markdown]
# <p style="text-align: center;" ><font size="+3"><u><b>Laboratory 3 Part 1: Linear Systems Theory Applied to Optical Imaging Systems</u></b></p>

# %% [markdown]
# <p style="text-align: left;" ><font size="+1"><b>Group #: 13  Team Members: Disha Mishra, Millan Patel, Sarah Khan </b></p>

# %% [markdown]
# <p style="text-align: left;" ><font size="+1"><b>Objectives</b></p>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <font color=black>
#
# - Understand linear system analysis in 1D and 2D, be able to perform convolution, cross correlation, and autocorrelation
# - Basic optical imaging system modeling
# - Simulate an optical system with a perfect lens
# - Measure the point spread function of your microscope
#
# </font>
# </div>

# %% [markdown]
# <p style="text-align: left;" ><font size="+1"><b>Introduction / Basic Rules</b></p>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <font color='black'>
#
# We have reviewed linear systems in 1D and extended the analysis to 2D signals. In this lab, you will first perform convolution exercises in Python. <br/>
# We will then write a simulator for a perfect optical system and see how the PSF of your microscope affects the final image output. </font>  </div>

# %% [markdown]
# # Convolution in Python

# %% [markdown]
# <div class="alert alert-block alert-success">
# <font color='black'>
#
# 1. If you have a signal $f$ that is on $N_f \times M_f$, and a signal $g$ that is $N_g \times M_g$, what is the size of ($f * g$)?
# </font>
# </div>

# %% [markdown]
# Say that ($f*g$) = C </br>
# We are now trying to find the size of C. We know that for a discrete convolution, our equation for each value in the matrix C is: </br>
# C(i,j) = $\sum_{n=0}^{N_f - 1}$ $\sum_{m=0}^{M_f - 1} f(n,m)g(i-n, j-m)$ </br>
# In this case, i and j are the dummy variables, but also the matrix spaces that are to be filled for C. Based on the convolution, this means that $0<i<N_f+N_g - 1$ and that $0<j<M_f+M_g - 1$
# </br>
# Thus, ($f*g$) = C has a size of $N_f+N_g - 1 \times M_f+M_g - 1$

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <font color='black'>
# Convolution in Python can be performed using `convolve` in 1D and `convolve2d` in 2D. To do this, first import the following functions:
#
# `import scipy` <br/>
# `from scipy.signal import convolve2d` <br/>
#
#
# By default, `convolve2d` returns the full size of the convolution results. <br/> For many applications, we want to keep the size of the output the same as one of the signals. The following would give an output that is the same size as $f$: <br/>
#
# `convolve2d(f, g, 'same')`<br/>
#
# Now let’s perform some convolutions and try to interpret the results.<br/>
# Load the image we provided, `SanFrancisco.npy`, into Python. <br/>
# Show the image below. Assume each pixel is 1mm by 1mm.
#
# </font>
# </div>

# %%
# imports
import numpy as np 
import matplotlib.pyplot as plt
import scipy 
from scipy.signal import convolve2d
from numpy.fft import fft2, fftshift, ifftshift, ifft2
from matplotlib import cm

# %% [markdown]
# <div class="alert alert-block alert-success">
# <font color='black'>
#
# 2. Now let’s perform some convolutions and try to interpret the results.<br/>
# Load the image we provided, `SanFrancisco.npy`, into Python. <br/>
# Show the image below. Assume each pixel is 1mm by 1mm.
#
# </font>
# </div>

# %%
sf = np.load("Lab3/SanFrancisco.npy")[:1023, :1023]; # load San Francisco Image
# print image 
x = plt.imshow(sf, cmap = "gray");
plt.colorbar(x, shrink = 0.8);
plt.title("San Francisco Map");
plt.xlabel("x values (mm)")
plt.ylabel("y values (mm)")
# Out:
# Text(0, 0.5, 'y values (mm)')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <font color='black'>
#
# 3. Download `functions.py` from Lab 3 course content on Blackboard and put it in your working directory. Make a 2D Gaussian kernel using the code below: <br/>
#
# `from functions import gauss2d` <br/>
# `h = gauss2d((52, 52), 3)`
#
# Assume the same pixel spacing (1 mm) as above. Paste the result below:
# </font>
# </div>

# %%
from functions import gauss2d
h = gauss2d((51,51), 3) # create 2D kernel
# print image
x = plt.imshow(h, cmap = "gray");
plt.colorbar(x, shrink = 0.8);
plt.title("2D Gaussian Kernel");
plt.xlabel("x values (mm)")
plt.ylabel("y values (mm)")
# Out:
# Text(0, 0.5, 'y values (mm)')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <font color='black'>
#
# 4. If the image is the input to an arbitrary system and `h` is the impulse response of the system, what is the output of the system? <br/> Keep the size of the output the same as the image. Paste your results below. Explain what you see in both the spatial domain and in the frequency domain (i.e., what is the transfer function of the system and how is it affecting the output?)
#
# </font>
# </div>

# %%
from numpy.fft import fft2, fftshift, ifftshift, ifft2
# original image
x = plt.imshow(sf, cmap = "gray");
plt.colorbar(x, shrink = 0.8);
plt.title("San Francisco Map");
plt.xlabel("x values (mm)")
plt.ylabel("y values (mm)")

cID = convolve2d(sf,h,'same', boundary = 'wrap') # convolution in the image domain
# Print image
plt.figure()
x = plt.imshow(cID, cmap = "gray");
plt.colorbar(x, shrink = 0.8);
plt.title("Convolution of San Francisco Map with 2D Gaussian Kernel ");
plt.xlabel("x values (mm)")
plt.ylabel("y values (mm)")

# fourier domain
# find sampling frequency 
N = 1023; # size of both images are 201x201
a = 1 # sampling period is every pixel (1 mm)
fs = (1 / (N*a)) * N

# Fourier Transform of convolution
Fft1 = fftshift(fft2(ifftshift(cID)))
FftOrig = fftshift(fft2(ifftshift(sf)))
                    

#Log 10 Fourier Transformation of Map
plt.figure()
real_F_plot = plt.imshow(np.log10(np.abs(FftOrig)), cmap = "gray", extent = [(-fs/2)*((N-1)/N),(fs/2)*((N-1)/N),(fs/2)*((N-1)/N),(-fs/2)*((N-1)/N)])
plt.colorbar(real_F_plot, shrink=0.8)
plt.title("Log 10 Magnitude of Fourier Transform of Map")
plt.xlabel("x frequency (1/mm)")
plt.ylabel("y frequency (1/mm)") 

#Log 10 Fourier Transformation of Convolved Map
plt.figure()
real_F_plot = plt.imshow(np.log10(np.abs(Fft1)), cmap = "gray", extent = [(-fs/2)*((N-1)/N),(fs/2)*((N-1)/N),(fs/2)*((N-1)/N),(-fs/2)*((N-1)/N)])
plt.colorbar(real_F_plot, shrink=0.8)
plt.title("Log 10 Magnitude of Fourier Transform of Convolved Map")
plt.xlabel("x frequency (1/mm)")
plt.ylabel("y frequency (1/mm)")
# Out:
# Text(0, 0.5, 'y frequency (1/mm)')

# %% [markdown]
# As we can see in the spatial domain, the convolved image is essentially smoother than the original image. The original image contains more lines and details in the image whereas the convolved image has smoothed out the very small details, bringing about a blurring effect on the image. This blurring image allows noise to be reduced, and also reduces detail in the image.
# </br>
# </br>
# The fourier transform of the convolved image is quite different from the fourier transform of the original image. The reason for this can be seen by analyzing how the Fourier Transformation of the convolution is computed. The fourier transform of the convolution is Y(f) = X(f)H(f) where X(f) is the fourier transform of the map image and H(f) is the transfer function. The impulse response of the convolved image is h, which is a gaussian kernel. The transfer function is the fourier transform of the impulse response, which is simply another gaussian function.
# </br>
# </br>
# Thus, in the fourier transform, the image we see is essentially obtained by multiplying the fourier transformation of the original map (as seen above) with a very similar gaussian kernel as shown in the previous question. By doing this, we are reducing the amount of high frequency values in the image, which can be seen in the frequency domain through the colorbar which shows lower high frequency values in the fourier transform of the convolved image. This decrease in frequency values after a convolution with a gaussian transfer function means that a gaussian function is a low pass filter as it is attentuating certain frequencies.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <font color='black'>
#
# 5. Now try to perform the same convolution in the Fourier domain using the convolution theorem and see if you get the same results back. <br/> Note that you would need to zero pad `h` to the same size as the image. You can achieve this with the `np.pad` function in Python. <br/> Paste your code and your image output below. Is the output (exactly) the same as what you got previously using convolution? Please explain what you see.
#
# </font>
# </div>

# %%
h1 = h # duplicate 2D kernel
h1 = np.pad(h,(486,486), 'constant', constant_values=0)
Xf= fftshift(fft2(ifftshift(sf))) #fourier transform of the map image 
Hf = fftshift(fft2(ifftshift(h1))) # fourier transform of the impulse response h1
Yf = Xf*Hf

plt.figure()
real_F_plot = plt.imshow(np.log10(np.abs(Yf)), cmap = "gray", extent = [(-fs/2)*((N-1)/N),(fs/2)*((N-1)/N),(fs/2)*((N-1)/N),(-fs/2)*((N-1)/N)])
plt.colorbar(real_F_plot, shrink=0.8)
plt.title("Log 10 Magnitude of Fourier Transform of Map")
plt.xlabel("x frequency (1/mm)")
plt.ylabel("y frequency (1/mm)") 

invYf = fftshift(ifft2(ifftshift(Yf)))
plt.figure()
real_F_plot = plt.imshow((np.abs(invYf)), cmap = "gray")
plt.colorbar(real_F_plot, shrink=0.8)
plt.title(" Magnitude of San Francisco Map")
plt.xlabel("x values (mm)")
plt.ylabel("y values (mm)") 

sub = invYf - cID
plt.figure()
s = plt.imshow((np.abs(sub)), cmap = "gray")
plt.colorbar(s, shrink=0.8)
plt.title("Subtracted Spatial Domain Images of Map")
plt.xlabel("x values (mm)")
plt.ylabel("y values (mm)")
# Out:
# Text(0, 0.5, 'y values (mm)')

# %% [markdown]
# Using the Y(f) = X(f)H(f) formula, we can get the fourier transform of the convolved output (Y(f)). To get this we do the fourier transforms of the map (to get X(f)) and impulse response (to get the transfer function H(f)). When Y(f) is obtained through the multiplication of the two, we can output this image to get the fourier transform of the convolved imaged. Additionally, we can take the inverse of Y(f) to get the convolved map image. As this formula, mathematically, gives us the exact same convolution as the previous method, we should see that the resulting images are the same, and we do! Visually, the convolved image in this question looks very similar to the previously attained convolved image. To further confirm this, we did a subtraction of the two convolved images and found an almost entirely dark image (the color bar has very very low intensities) and the difference we see are likely due to some sort of noise or rounding errors, but we can confidently say that these images are the same or at least very very close to being the same! Again, this makes sense due to the math explained above.
# </br>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <font color='black'>
# 6. Make the following two filters/kernels in Python: <br/>
# Perform convolution of each filter with the image. Paste your image below. Explain what you see using both spatial domain and frequency domain descriptions.
# </font>
# </div>

# %% [markdown]
# <img src="Lab3/kernel.png" style="width:400px">

# %%
filt1 = np.array([[-1,0,1], [-2,0,2], [-1,0,1]]) # first 2D filter
filt2 = np.array([[-1,-2,-1], [0,0,0], [1,2,1]]) # 2nd 2D filter

plt.figure()
x = plt.imshow(filt1, cmap = "gray")
plt.colorbar(x, shrink = 0.8)
plt.title("Filter 1");
plt.xlabel("x values (mm)")
plt.ylabel("y values (mm)")

fft_Filt1= fftshift(fft2(ifftshift(filt1))) #fourier transform of the convolved image
plt.figure()
x = plt.imshow(np.abs(fft_Filt1), cmap = "gray", extent = [(-fs/2)*((N-1)/N),(fs/2)*((N-1)/N),(fs/2)*((N-1)/N),(-fs/2)*((N-1)/N)])
plt.colorbar(x, shrink = 0.8)
plt.title("Fourier Transform of First Filter Convolution")
plt.xlabel("x frequency (1/mm)")
plt.ylabel("y frequency (1/mm)")

plt.figure()
x = plt.imshow(filt2, cmap = "gray")
plt.colorbar(x, shrink = 0.8)
plt.title("Filter 2");
plt.xlabel("x values (mm)")
plt.ylabel("y values (mm)")

fft_Filt2= fftshift(fft2(ifftshift(filt2))) #fourier transform of the convolved image
plt.figure()
x = plt.imshow(np.abs(fft_Filt2), cmap = "gray", extent = [(-fs/2)*((N-1)/N),(fs/2)*((N-1)/N),(fs/2)*((N-1)/N),(-fs/2)*((N-1)/N)])
plt.colorbar(x, shrink = 0.8)
plt.title("Fourier Transform of Second Filter Convolution")
plt.xlabel("x frequency (1/mm)")
plt.ylabel("y frequency (1/mm)")

## Filter 1 calculations
filt1Conv = convolve2d(sf,filt1,'same', boundary = 'wrap') # convolution in the image domain
# Print image
plt.figure()
x = plt.imshow((filt1Conv), cmap = "gray")
plt.colorbar(x, shrink = 0.8)
plt.title("Convolution of San Francisco Map with First Filter");
plt.xlabel("x values (mm)")
plt.ylabel("y values (mm)")

fft_1= fftshift(fft2(ifftshift(filt1Conv))) #fourier transform of the convolved image
plt.figure()
x = plt.imshow(np.abs(fft_1), cmap = "gray", extent = [(-fs/2)*((N-1)/N),(fs/2)*((N-1)/N),(fs/2)*((N-1)/N),(-fs/2)*((N-1)/N)])
plt.colorbar(x, shrink = 0.8)
plt.title("Fourier Transform of First Filter Convolution")
plt.xlabel("x frequency (1/mm)")
plt.ylabel("y frequency (1/mm)")

## Filter 2 calculations
filt2Conv = convolve2d(sf,filt2,'same', boundary = 'wrap') # convolution in the image domain
# Print image
plt.figure()
x = plt.imshow(filt2Conv, cmap = "gray")
plt.colorbar(x, shrink = 0.8)
plt.title("Convolution of San Francisco Map with Second Filter")
plt.xlabel("x values (mm)")
plt.ylabel("y values (mm)")

fft_2= fftshift(fft2(ifftshift(filt2Conv))) #fourier transform of the convolved image 
plt.figure()
x = plt.imshow(np.abs(fft_2), cmap = "gray", extent = [(-fs/2)*((N-1)/N),(fs/2)*((N-1)/N),(fs/2)*((N-1)/N),(-fs/2)*((N-1)/N)])
plt.colorbar(x, shrink = 0.8)
plt.title("Fourier Transform of Second Filter Convolution")
plt.xlabel("x frequency (1/mm)")
plt.ylabel("y frequency (1/mm)")
# Out:
# Text(0, 0.5, 'y frequency (1/mm)')

# %% [markdown]
# Clearly, the filters remove a lot of detail from the original image and we cannot make out the map after applying the filter. The two filters that we are given are transposes of each other, and by looking at the fourier transforms of the filters, we see that there are two distinct peaks on each filter; Filter 1 has 2 peaks(white boxes) at y-frequency = 0, and Filter 2 has 2 peaks(white boxes) at x-frequency = 0. When we convolve the San Francisco Map with these filters, we see that the convolution with Filter 1 has faint vertical lines in the spatial domain image. The map image convolved with Filter 2 follows a similar trend with faint horizontal lines in the spatial domain. These lines are likely visible because they correspond with the peak frequencies in the fourier domain of the filter. These peaks can also be seen in the fourier transforms of the two convolved images: The convolved image with Filter 1 has 2 peaks at y-frequency = 0 and the convolved image with Filter 2 has 2 peaks at x-frequency = 0. Also, we observe that these peaks aren't perfect and there are other smaller peaks around the main peaks in the fourier domain of the convolved images. This is likely due to the fact that the resolution of the filter being so low compared to the resolution of the image. Also, the filter itself does not follow a perfect sinusoidal function with constant frequencies. All in all, this is why the lines we see in the spatial domain image aren't perfectly straight.

# %% [markdown]
# # Pupil function and PSF Simulation

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <font color='black'> In this part of the lab, you will simulate a few pupil functions and compute the corresponding Point Spread Function (PSF) and Optical Transfer Function (OTF). </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <font color='black'>
#
# 1. Let’s first simulate a circular pupil function [`P(x,y)` in the notes]. <br/> On a 1001 by 1001 grid with a 0.1 mm sampling interval, simulate a centered circular pupil function with 12mm diameter. Paste your result below with axis labels and colorbar.
#
# </font>
# </div>

# %%
# Pupil Function
N = 1001
a = 0.1
lim = (N-1)/2 * a
xr = np.linspace(-lim,lim,N)
yr = np.linspace(-lim,lim,N)
fs = N / (2*lim)
[X,Y] = np.meshgrid(xr,yr)
P = ((np.sqrt(X**2 + Y**2) < 6)) * 1
x=plt.imshow(P, cmap='gray', extent=[-lim,lim,lim,-lim])
plt.colorbar(x,shrink=0.8)
plt.xlabel("x-position (mm)")
plt.ylabel("y-position (mm)")
plt.title("12mm Diameter Pupil Function")
# Out:
# Text(0.5, 1.0, '12mm Diameter Pupil Function')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <font color='black'>
#
# 2. Compute the PSF of the pupil function. We can presume the axes of the pupil function are already scaled to the right imaging plane in this lab, i.e., you can compute the Fourier transform or autocorrelation of the pupil function directly. Paste your code below. Please also include 1) a surface plot of the PSF, 2) a surface plot of the log10 transformed PSF. For both figures, please zoom in on the central 201 by 201 pixels and include axis labels and colorbar. <br/>
#
# You can produce a surface plot using the `plot_surface` function in `matplotlib`. Take a look at the example at https://matplotlib.org/stable/gallery/mplot3d/surface3d.html. This function plots `Z` which is a function of 2D coordinate matrices `X` and `Y` produced from `np.meshgrid`. Note that you need to provide the keyword argument `subplot_kw={"projection": "3d"}` in order to use `plot_surface`. <br/>
# </font>
# </div>

# %%
# Point Spread Function
plt.figure()
PSF = (np.abs(fftshift(fft2(ifftshift(P)))) ** 2)
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(X[400:601,400:601], Y[400:601,400:601], PSF[400:601,400:601], cmap=cm.jet, linewidth=0, antialiased=False)
fig.colorbar(surf, ax=ax, shrink=0.5)
ax.set_xlabel("x-position (mm)")
ax.set_ylabel("y-position (mm)")
ax.set_zlabel("Magnitude")
ax.set_title("Point Spread Function")
plt.show()

plt.figure()
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(X[400:601,400:601], Y[400:601,400:601], np.log10(PSF[400:601,400:601]), cmap=cm.jet, linewidth=0, antialiased=False)
fig.colorbar(surf, ax=ax, shrink=0.5)
ax.set_xlabel("x-position (mm)")
ax.set_ylabel("y-position (mm)")
ax.set_zlabel("Log10 Magnitude")
ax.set_title("Log10 Magnitude of Point Spread Function")
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <font color='black'>
#
# From the PSF, we can compute the Fourier domain transfer function of the system. This function is called the Optical Transfer Function (OTF), and is equal to the Fourier transform of the PSF normalized by the totally area under the OTF, or equivalently, the DC value (`frequency = [0, 0]`) of the Fourier transform.
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <font color='black'>
#
# 3. Compute the OTF. Past your code below and include both a regular plot (`imshow`) and a surface plot (`plot_surface`) of the OTF below.
# </font>
# </div>

# %%
# Optical Transfer Function
plt.figure()
OTF = fftshift(fft2(ifftshift(PSF)))
OTF = OTF / OTF[500,500]
x=plt.imshow(np.abs(OTF), cmap='gray', extent = [-fs/2,fs/2,fs/2,-fs/2])
plt.colorbar(x, shrink=0.8)
plt.xlabel("x-frequency (1/mm)")
plt.ylabel("y-frequency (1/mm)")
plt.title("Magnitude of Optical Transfer Function")

plt.figure()
x=plt.imshow(np.log10(np.abs(OTF)), cmap='gray', extent = [-fs/2,fs/2,fs/2,-fs/2])
plt.colorbar(x, shrink=0.8)
plt.xlabel("x-frequency (1/mm)")
plt.ylabel("y-frequency (1/mm)")
plt.title("Log10 Magnitude of Optical Transfer Function")

plt.figure()
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ur = np.linspace(-fs/2 * (N-1)/N,fs/2 * (N-1)/N,N)
vr = np.linspace(-fs/2 * (N-1)/N,fs/2 * (N-1)/N,N)
U, V = np.meshgrid(ur, vr)
surf = ax.plot_surface(U, V, np.abs(OTF), cmap=cm.jet, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5)
ax.set_xlabel("x-frequency (1/mm)")
ax.set_ylabel("y-frequency (1/mm)")
ax.set_title("Magnitude of Optical Transfer Function")
ax.set_zlabel("Magnitude")
plt.show()

plt.figure()
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(U, V, np.log10(np.abs(OTF)), cmap=cm.jet, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5)
ax.set_xlabel("x-frequency (1/mm)")
ax.set_ylabel("y-frequency (1/mm)")
ax.set_title("Log10 Magnitude of Optical Transfer Function")
ax.set_zlabel("Log10 Magnitude")
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <font color='black'>
#
# 4. Now let’s simulate what an image passing through a system with this pupil function looks like. Make a star pattern by calling the `make_star` function provided in lab 3 course content. You need to provide the axes of your image to the function. Presuming you called your axes variables `x` and `y` (Note: both are 1D arrays instead of 2D from meshgrid), you can make a star pattern with:
#
# `from functions import make_star` <br/>
# `star = make_star(x, y)`
#
# Use the same axes as above (1001 by 1001 grid with a 0.1 mm sampling interval), plot what the star pattern would look like through a system with the PSF and OTF you just calculated. Paste your code and your results below. Explain what you observe.
# </font>
# </div>

# %%
from functions import make_star
star = make_star(xr,yr)
x=plt.imshow(star, cmap='gray')
plt.colorbar(x, shrink=0.8)
plt.title("Image Input")
plt.xlabel("x-position (mm)")
plt.ylabel("y-position (mm)")

# Image Output
plt.figure()
FT_star = fftshift(fft2(ifftshift(star)))
FT_output = FT_star * OTF
img_out = ifftshift(ifft2(fftshift(FT_output)))
x=plt.imshow(np.abs(img_out), cmap='gray',extent=[-50,50,50,-50])
plt.colorbar(x,shrink=0.8)
plt.title("Image Output")
plt.xlabel("x-position (mm)")
plt.ylabel("y-position (mm)")
# Out:
# Text(0, 0.5, 'y-position (mm)')

# %% [markdown]
# The image output and input are very similar. The only difference is that the output is slightly blurrier and has lower resolution than the image input. This can seen by looking at the center of the star where the spoke frequency is higher. This imaging system (OTF) is working like a low pass filter, eliminating the high frequency portions of the original image.

# %% [markdown]
# The general equations we used to find the output image are:
#
# $PSF = FFT(Pupil)^2$  <br/>
# $OTF = FFT(PSF)/FFT(PSF)[f=0,0]$  <br/>
# $Output = IFFT(FFT(Input) * OTF)$

# %% [markdown]
# <div class="alert alert-block alert-success">
# <font color='black'>
#
# 5. Now let’s the make the aperture smaller. Make a 3mm diameter pupil function. Compute the PSF, OTF, and image output and paste the images below. <br/> What do you see? How does this relate to the observation from the last lab?</font>
# </div>

# %%
# Pupil Function
P = ((np.sqrt(X**2 + Y**2) < 3/2)) * 1
x=plt.imshow(P, cmap='gray', extent=[-lim,lim,lim,-lim])
plt.colorbar(x,shrink=0.8)
plt.xlabel("x-position (mm)")
plt.ylabel("y-position (mm)")
plt.title("3mm Diameter Pupil Function")

# Point Spread Function
plt.figure()
PSF = np.abs(fftshift(fft2(ifftshift(P)))) ** 2
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(X, Y, np.abs(PSF), cmap=cm.jet, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5)
ax.set_xlabel("x-position (mm)")
ax.set_ylabel("y-position (mm)")
ax.set_zlabel("Magnitude")
ax.set_title("Magnitude of Point Spread Function")
plt.show()

plt.figure()
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(X, Y, np.log10(PSF), cmap=cm.jet, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5)
ax.set_xlabel("x-position (mm)")
ax.set_ylabel("y-position (mm)")
ax.set_zlabel("Log10 Magnitude")
ax.set_title("Log10 Magnitude of Point Spread Function")
plt.show()

# Optical Transfer Function
plt.figure()
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
OTF = fftshift(fft2(ifftshift(PSF)))
OTF = OTF / OTF[500,500]
surf = ax.plot_surface(U, V, np.abs(OTF), cmap=cm.jet, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5)
ax.set_xlabel("x-frequency (1/mm)")
ax.set_ylabel("y-frequency (1/mm)")
ax.set_title("Magnitude of Optical Transfer Function")
ax.set_zlabel("Magnitude")

plt.figure()
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(U, V, np.log10(np.abs(OTF)), cmap=cm.jet, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5)
ax.set_xlabel("x-frequency (1/mm)")
ax.set_ylabel("y-frequency (1/mm)")
ax.set_title("Log10 Magnitude of Optical Transfer Function")
ax.set_zlabel("Log10 Magnitude")

# Image Output
plt.figure()
FT_star = fftshift(fft2(ifftshift(star)))
FT_output = FT_star * OTF
img_out = ifftshift(ifft2(fftshift(FT_output)))
x=plt.imshow(np.abs(img_out), cmap='gray',extent=[-lim,lim,lim,-lim])
plt.colorbar(x,shrink=0.8)
plt.title("Image Output")
plt.xlabel("x-position (mm)")
plt.ylabel("y-position (mm)")
# Out:
# Text(0, 0.5, 'y-position (mm)')

# %% [markdown]
# The image output we get from the smaller diameter pupil function is much blurrier than the first image output. The smaller pupil function has a point spread function with a larger diameter, which directly relates to the blur in the final image output. In the last lab, we observed that smaller aperture images make it more difficult to see high frequency regions. This is consistent with what we see here. The smaller pupil function relates to a smaller aperture size so it makes sense that it is harder to resolve the high frequency line pairs in this image.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <font color='black'>
#
# Of course not all optical systems have circular pupil functions. Now let’s simulate a few other pupil functions and see how they affect the image output. <br/> Construct a pupil function with an annulus and cross shaped obstruction:
# </font>
# </div>

# %% [markdown]
# <img src="Lab3\Pupil_cross.png" style="width:400px">

# %% [markdown]
# <div class="alert alert-block alert-success">
# <font color='black'>
#
# 6. You can construct this in Python by making a disc of 12 mm diameter, subtract a disc of 8 mm diameter, and subtract a central vertical band and a central horizontal band of width 4 mm. <br/>
# The Matlab logical operations are going to be helpful for this step:
#
# - and: `np.logical_and(A, B)`
# - or: `np.logical_or(A, B)`
# - not: `np.logical_not(A)`
#
# Paste your code and your pupil function below.
# </font>
# </div>

# %%
P = np.logical_and(np.sqrt(X**2 + Y**2) < 6, np.sqrt(X**2 + Y**2) > 4)
A = np.logical_or(X > 2, X < -2)
B = np.logical_or(Y > 2, Y < -2)
P = np.logical_and(P,A)
P = np.logical_and(P,B)
x=plt.imshow(P, cmap='gray', extent=[-lim,lim,lim,-lim])
plt.colorbar(x, shrink=0.8)
plt.xlabel("x-position (mm)")
plt.ylabel("y-position (mm)")
plt.title("Pupil Function")
# Out:
# Text(0.5, 1.0, 'Pupil Function')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <font color='black'>
#
# 7. Compute the PSF, OTF, and final image output of the star pattern. Paste all images below. Interpret the image output. </font>
# </div>

# %%
# Point Spread Function
plt.figure()
PSF = np.abs(fftshift(fft2(ifftshift(P)))) ** 2
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(X, Y, np.abs(PSF), cmap=cm.jet, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5)
ax.set_xlabel("x-position (mm)")
ax.set_ylabel("y-position (mm)")
ax.set_zlabel("Magnitude")
ax.set_title("Magnitude of Point Spread Function")
plt.show()

plt.figure()
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(X, Y, np.log10(PSF), cmap=cm.jet, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5)
ax.set_xlabel("x-position (mm)")
ax.set_ylabel("y-position (mm)")
ax.set_zlabel("Log10 Magnitude")
ax.set_title("Log10 Magnitude of Point Spread Function")
plt.show()

plt.figure()
x=plt.imshow(np.abs(PSF[400:601]), cmap='jet', extent=[-10,10,10,-10])
plt.colorbar(x, shrink=0.8)
plt.xlabel("x-position (mm)")
plt.ylabel("y-position (mm)")
plt.title("Magnitude of Point Spread Function")

# Optical Transfer Function
plt.figure()
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
OTF = fftshift(fft2(ifftshift(PSF)))
OTF = OTF / OTF[500,500]
surf = ax.plot_surface(U, V, np.abs(OTF), cmap=cm.jet, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5)
ax.set_xlabel("x-frequency (1/mm)")
ax.set_ylabel("y-frequency (1/mm)")
ax.set_title("Magnitude of Optical Transfer Function")
ax.set_zlabel("Magnitude")

plt.figure()
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(U, V, np.log10(np.abs(OTF)), cmap=cm.jet, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5)
ax.set_xlabel("x-frequency (1/mm)")
ax.set_ylabel("y-frequency (1/mm)")
ax.set_title("Log10 Magnitude of Optical Transfer Function")
ax.set_zlabel("Log10 Magnitude")

plt.figure()
x=plt.imshow(np.abs(OTF), cmap='jet', extent=[-fs/2*(N-1)/N,fs/2*(N-1)/N,fs/2*(N-1)/N,-fs/2*(N-1)/N])
plt.colorbar(x, shrink=0.8)
plt.xlabel("x-frequency (1/mm)")
plt.ylabel("y-frequency (1/mm)")
plt.title("Magnitude of Optical Transfer Function")

# Image Output
plt.figure()
FT_star = fftshift(fft2(ifftshift(star)))
FT_output = FT_star * OTF
img_out = ifftshift(ifft2(fftshift(FT_output)))
x=plt.imshow(np.abs(img_out), cmap='gray',extent=[-lim,lim,lim,-lim])
plt.colorbar(x,shrink=0.8)
plt.title("Image Output")
plt.xlabel("x-position (mm)")
plt.ylabel("y-position (mm)")
# Out:
# Text(0, 0.5, 'y-position (mm)')

# %% [markdown]
# The image output for this pupil function is quite blury and towards the center, high frequency regions there are small lines that seem to be coming out of the center, which could point to aliasing. However, it is also likely that the new pupil function is influencing these lines to occur, because the OTF created by this function. The image of the OTF has a radial look, but also contains some holes within the image, which means that when this OTF image is convolved with the star image, there will not be a clean blur as we saw in the earlier questions, but rather some of the lines will start to curve instead of going straight inwards due to the radial changes and holes that are seen in the OTF. This uneven blur is also further explained by the idea that the pupil function has high intensity peaks around the radius (generally if we are thinking of the center as the center of a compass, the peaks occur in the  NW, SW, NE, and SE regions) and these regions are blurrier in the output image as the peaks on the pupil function are where the filtering and blurring occur. The N, E, W, and S regions on the other hand do not have those peaks on the pupil function image which is why there is less blending in those areas and also a few pronounced lines, which again may point to aliasing.
#
# The aliasing is most pronounced directly north, south, east, and west of the center. At the NW, SW, NE, and SE regions, there seems to be less aliasing. The areas where there is most aliasing corresponds with the dark regions of the pupil function. This makes sense because aliasing is an inability to resolve high frequency structures due to a low sampling rate. We saw that lower pupil sizes make it harder to resolve high frequencies, so it makes sense that the dark regions (pupil size approaching zero) is also unable to resolve high frequency structures.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <font color='black'>
#
# 8. Make the following pupil function in Python. There are two circular apertures of 6mm diameter, each diagonally offset from the origin by 3 mm in the x and y direction.  <br/> Paste your code and your pupil function below. </font>
# </div>

# %% [markdown]
# <img src="Lab3\Pupil_6mm.png" style="width:400px">

# %%
P = np.logical_or(np.sqrt((X+3)**2 + (Y-3)**2) < 3, np.sqrt((X-3)**2 + (Y+3)**2) < 3)
x=plt.imshow(P, cmap='gray', extent=[-50,50,50,-50])
plt.colorbar(x, shrink=0.8)
plt.xlabel("x-position (mm)")
plt.ylabel("y-position (mm)")
plt.title("Pupil Function")
# Out:
# Text(0.5, 1.0, 'Pupil Function')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <font color='black'>
#
# 9. Compute the PSF, OTF, and final image output of the star pattern. Paste all images below. Interpret the image output.  </font>
# </div>

# %%
# Point Spread Function
plt.figure()
PSF = np.abs(fftshift(fft2(ifftshift(P)))) ** 2
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(X, Y, np.abs(PSF), cmap=cm.jet, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5)
ax.set_xlabel("x-position (mm)")
ax.set_ylabel("y-position (mm)")
ax.set_zlabel("Magnitude")
ax.set_title("Magnitude of Point Spread Function")
plt.show()

plt.figure()
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(X, Y, np.log10(PSF), cmap=cm.jet, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5)
ax.set_xlabel("x-position (mm)")
ax.set_ylabel("y-position (mm)")
ax.set_zlabel("Log10 Magnitude")
ax.set_title("Log10 Magnitude of Point Spread Function")
plt.show()

plt.figure()
x=plt.imshow(np.abs(PSF[400:601]), cmap='jet', extent=[-10,10,10,-10])
plt.colorbar(x, shrink=0.8)
plt.xlabel("x-position (mm)")
plt.ylabel("y-position (mm)")
plt.title("Magnitude of Point Spread Function")

# Optical Transfer Function
plt.figure()
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
OTF = fftshift(fft2(ifftshift(PSF)))
OTF = OTF / OTF[500,500]
surf = ax.plot_surface(U, V, np.abs(OTF), cmap=cm.jet, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5)
ax.set_xlabel("x-frequency (1/mm)")
ax.set_ylabel("y-frequency (1/mm)")
ax.set_title("Magnitude of Optical Transfer Function")
ax.set_zlabel("Magnitude")

plt.figure()
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(U, V, np.log10(np.abs(OTF)), cmap=cm.jet, linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5)
ax.set_xlabel("x-frequency (1/mm)")
ax.set_ylabel("y-frequency (1/mm)")
ax.set_title("Log10 Magnitude of Optical Transfer Function")
ax.set_zlabel("Log10 Magnitude")

plt.figure()
x=plt.imshow(np.abs(OTF), cmap='jet', extent=[-fs/2*(N-1)/N,fs/2*(N-1)/N,fs/2*(N-1)/N,-fs/2*(N-1)/N])
plt.colorbar(x, shrink=0.8)
plt.xlabel("x-frequency (1/mm)")
plt.ylabel("y-frequency (1/mm)")
plt.title("Magnitude of Optical Transfer Function")

# Image Output
plt.figure()
FT_star = fftshift(fft2(ifftshift(star)))
FT_output = FT_star * OTF
img_out = ifftshift(ifft2(fftshift(FT_output)))
x=plt.imshow(np.abs(img_out), cmap='gray',extent=[-lim,lim,lim,-lim])
plt.colorbar(x,shrink=0.8)
plt.title("Image Output")
plt.xlabel("x-position (mm)")
plt.ylabel("y-position (mm)")
# Out:
# Text(0, 0.5, 'y-position (mm)')

# %% [markdown]
# This output image is better focused than the previous output image shown in Question 7, and the reason that we see this output image is a very similar explanation as in Question 7. The change in pupil function to two diagonally placed circles once again changes the blur in this image. When looking closely at the center of the output image, you can see two gray areas in the top right and bottom left and lines in the top left and bottom right. This relates to the the shape of the pupil function where there are light regions in the top right and bottom left and dark regions in the top left and bottom right. Again, this occurs due to the OTF of the function, which contains high frequencies in the center and rightwards slanting diagonal areas, which makes the center and top right / bottom left of the resulting output image have more blur whereas the top left and lower right portions of the image have less blur (the spokes in the center come in further if you look closely. Thus, tt is clear from these last couple of exercises that the shape of the pupil function can affect the output image of the star.
